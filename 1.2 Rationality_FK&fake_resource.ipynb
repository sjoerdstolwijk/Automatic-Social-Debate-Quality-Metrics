# %% [markdown]
# # Comparing dictionary and manual coding: Rationality
# Data: *Data_FixedCodingMistakes_noICR_ReadyForAnalysis_with_comments*.
#
# This script will get rationality score based on the following methods:
# 1. Manually coding result: RATIONALITY_DUMMY
# 2. Flesch-Kincaid index via function `textstat.flesch_reading_ease`
# 3. Nithyanand et al. (2017b): a list of websites that is related to fake news
# 4. Munger and Phillips (2019): “alternative information networks”

# %%
import pandas as pd
import os
import textstat
import numpy as np
import re

# %% [markdown]
# ### Read manual code and get the socre
# only use colums about meta-information and about rationality

# %%
compare_rationality = pd.read_csv('data/full_data.csv')
compare_rationality.head()
# Out:
#              StartDate         RecordedDate        IPAddress  Finished  Coder  \
# 0   5/30/2021 13:03:17   5/30/2021 13:04:17     62.194.51.29         1      6
# 1  10/11/2021 10:34:05  10/11/2021 10:36:46  213.127.109.191         1      6
# 2    9/9/2021 18:49:48    9/9/2021 18:51:32    213.127.110.0         1      6
# 3    6/6/2021 16:12:46    6/6/2021 16:16:16   213.127.76.145         1      6
# 4   6/13/2021 13:25:49   6/13/2021 13:27:28   213.127.82.232         1      6
#
#                                                   ID  Mark_ID  Genre  \
# 0  UgyPHwv8G0cDE6-wEgl4AaABAg.8_0ZjJKSJty8_0kXGkAd2U      119      0
# 1  Ugx2WXq9UdV8mPPjejJ4AaABAg.8yHCKV0Boe58yYRxEQEF45      282      1
# 2                                1110578710648890000      372      2
# 3  UgwUPFScjJ0MCeaP2F54AaABAg.8lvp3fc9Euf8lvvgsUgEgV      769      0
# 4  UgwWKCWtSJdFvjGHvTp4AaABAg.8kUC5dGrQ2H8kUDRihE2f3     1206      0
#
#    topiccode  Platform  ...  dislikeCount_video likeCount_video  \
# 0          0         1  ...                 NaN             NaN
# 1          2         1  ...               195.0          3817.0
# 2          4         2  ...                 NaN             NaN
# 3          0         1  ...                 NaN             NaN
# 4          0         1  ...                 NaN             NaN
#
#    date_difference  commentCount_video  replyCount_comment    topic  \
# 0              NaN                 NaN                 NaN      NaN
# 1            743.0              1748.0                 NaN  economy
# 2              NaN                 NaN                 NaN      NaN
# 3              NaN                 NaN                 NaN      NaN
# 4              NaN                 NaN                 NaN      NaN
#
#    subscribers  HATELIST_FOCUSED_DUMMY  Time_comment_year Time_video_year
# 0          NaN                       0               2017          2017.0
# 1    3630000.0                       0               2019          2019.0
# 2          NaN                       0               2019             NaN
# 3          NaN                       0               2018          2018.0
# 4          NaN                       0               2018          2018.0
#
# [5 rows x 81 columns]

# %%
len(compare_rationality)
# Out:
# 3862

# %% [markdown]
# Double check dummy variable calculation

# %%
def mannual_concrete(compare_rationality):
    for index, d in compare_rationality.iterrows():
        allsum = sum(d[['Reasoning','BackgroundInfo','ExternalEvidence']])
        compare_rationality.loc[index,'mannual_sum'] = allsum
        if allsum >= 1:
            compare_rationality.loc[index,'mannual_dummy'] = 1
        else:
            compare_rationality.loc[index,'mannual_dummy'] = 0
    return compare_rationality

# %%
compare_rationality = mannual_concrete(compare_rationality)

# %%
f = compare_rationality[['RATIONALITY_DUMMY','mannual_dummy']]
f.corr()
# Out:
#                    RATIONALITY_DUMMY  mannual_dummy
# RATIONALITY_DUMMY                1.0            1.0
# mannual_dummy                    1.0            1.0

# %% [markdown]
# ### Calculate FK score

# %%
def F_K_score(compare_rationality):
    for index, t in compare_rationality.iterrows():
        if type(t['commentText']) != float:
            f=textstat.flesch_reading_ease(str(t['commentText'])) 
            compare_rationality.loc[index,'FK_SCORE'] = f
        else:
            compare_rationality.loc[index,'FK_SCORE'] = np.nan
    return compare_rationality

# %%
compare_rationality = pd.DataFrame(F_K_score(compare_rationality))

# %% [markdown]
# ### Find false sources

# %%
def detect_false_sources(text):
    urls = re.findall('[^ :/((www))]*?\.com',text)
    urls = urls+re.findall('[^ :/((www))]*?\.org',text)
    count = 0
    for url in urls:
        name = '.'.join(url.split('.')[-2:])
        if name in false_sources:
            print(repr(name))
            count +=1
    return count

# %%
def detect_ain(text):
    count = 0
    for a in ain:
        ainn = re.findall(a,text)
        if ainn:
            print(ainn)
            count += len(ain)
    return count

# %%
false_sources=pd.read_csv('https://raw.githubusercontent.com/BigMcLargeHuge/opensources/master/sources/sources.csv')["Unnamed: 0"].tolist()
ain = pd.read_csv('data/dictionaries/labeled_ain.csv')['title'].tolist()
print(len(false_sources),len(ain))
# Out:
# 833 51

# %%
for index, text in compare_rationality.iterrows():
    compare_rationality.loc[index, 'FALSE_SCOURCES'] = 0
    if type(text['commentText']) == float:
        compare_rationality.loc[index, 'FALSE_SCOURCES'] = np.nan
        continue
    compare_rationality.loc[index, 'FALSE_SCOURCES'] = detect_false_sources(text['commentText'])
    compare_rationality.loc[index, 'FALSE_SCOURCES'] += detect_ain(text['commentText'])
# Out:
# 'dailykos.com'
# ['Project Veritas']

# %% [markdown]
# As the result shows, only two comments contain false resources. So this methods may not sensitive in detecting rationality.

# %% [markdown]
# ### Check descriptive result

# %%
compare_rationality.loc[compare_rationality['FK_SCORE']<10,['commentText','RATIONALITY_DUMMY','FK_SCORE']]
# Out:
#                                             commentText  RATIONALITY_DUMMY  \
# 72                              Hahaha...karma bitch!!!                  0
# 97                 @Fernando Margellan BODEGA BABIES!!!                  0
# 164                                             Exactly                  0
# 182                                          beautiful!                  0
# 205                                            "Comedy"                  0
# ...                                                 ...                ...
# 3725                          I LOVE YOUUUUUUUUUUUUUUUU                  0
# 3779        Hahahahahhahahahhaha you don't have a clue.                  0
# 3782  Hahahahahahaha. They are going to federal jail...                  0
# 3792                       HAHAHAHahahahah...hah...huh?                  0
# 3846  I thought you did Billie Holiday real good of ...                  1
#
#       FK_SCORE
# 72       -6.70
# 97        8.20
# 164     -47.99
# 182     -47.99
# 205     -47.99
# ...        ...
# 3725   -278.44
# 3779      6.17
# 3782    -22.27
# 3792   -555.59
# 3846    -13.79
#
# [139 rows x 3 columns]

# %%
compare_rationality['FK_SCORE'].describe()
# Out:
# count    3862.000000
# mean       73.362890
# std        33.888733
# min      -555.590000
# 25%        60.820000
# 50%        77.740000
# 75%        91.780000
# max       206.840000
# Name: FK_SCORE, dtype: float64

# %% [markdown]
# The reason FK score doesn't work may be that comments are short. The equation of [FK score](https://en.wikipedia.org/wiki/Flesch–Kincaid_readability_tests) is not suitable for short texts.

# %%
compare_rationality['RATIONALITY_DUMMY'].describe()
# Out:
# count    3862.000000
# mean        0.180476
# std         0.384634
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# Name: RATIONALITY_DUMMY, dtype: float64

# %%
compare_rationality
# Out:
#                 StartDate         RecordedDate        IPAddress  Finished  \
# 0      5/30/2021 13:03:17   5/30/2021 13:04:17     62.194.51.29         1
# 1     10/11/2021 10:34:05  10/11/2021 10:36:46  213.127.109.191         1
# 2       9/9/2021 18:49:48    9/9/2021 18:51:32    213.127.110.0         1
# 3       6/6/2021 16:12:46    6/6/2021 16:16:16   213.127.76.145         1
# 4      6/13/2021 13:25:49   6/13/2021 13:27:28   213.127.82.232         1
# ...                   ...                  ...              ...       ...
# 3857   8/19/2021 14:50:13   8/19/2021 14:54:28     62.194.51.29         1
# 3858   8/19/2021 15:10:27   8/19/2021 15:12:21     62.194.51.29         1
# 3859   10/6/2021 16:08:39   10/6/2021 16:10:42  213.127.113.113         1
# 3860  10/15/2021 18:30:04  10/15/2021 18:35:40  213.127.109.191         1
# 3861  11/19/2021 17:49:17  11/19/2021 17:51:04  213.127.109.191         1
#
#       Coder                                                 ID   Mark_ID  \
# 0         6  UgyPHwv8G0cDE6-wEgl4AaABAg.8_0ZjJKSJty8_0kXGkAd2U       119
# 1         6  Ugx2WXq9UdV8mPPjejJ4AaABAg.8yHCKV0Boe58yYRxEQEF45       282
# 2         6                                1110578710648890000       372
# 3         6  UgwUPFScjJ0MCeaP2F54AaABAg.8lvp3fc9Euf8lvvgsUgEgV       769
# 4         6  UgwWKCWtSJdFvjGHvTp4AaABAg.8kUC5dGrQ2H8kUDRihE2f3      1206
# ...     ...                                                ...       ...
# 3857      6                                1152219467579100000  10000695
# 3858      6                                1085362296472430000  10007008
# 3859      6        UghFY3QJ6nmT_ngCoAEC.7-H0Z7--wxd8goqpaPs-bl  20000102
# 3860      6                         UgyWabsmmnq3zam4DgZ4AaABAg  20000418
# 3861      6                         UgwPOHIDyICm10k0Mvx4AaABAg  20001003
#
#       Genre  topiccode  Platform  ...  replyCount_comment    topic  \
# 0         0          0         1  ...                 NaN      NaN
# 1         1          2         1  ...                 NaN  economy
# 2         2          4         2  ...                 NaN      NaN
# 3         0          0         1  ...                 NaN      NaN
# 4         0          0         1  ...                 NaN      NaN
# ...     ...        ...       ...  ...                 ...      ...
# 3857      0          4         2  ...                 NaN      NaN
# 3858      1          4         2  ...                 NaN      NaN
# 3859      0          3         1  ...                 NaN     east
# 3860      2          3         1  ...                 0.0     east
# 3861      0          3         1  ...                 1.0     east
#
#       subscribers  HATELIST_FOCUSED_DUMMY  Time_comment_year  Time_video_year  \
# 0             NaN                       0               2017           2017.0
# 1       3630000.0                       0               2019           2019.0
# 2             NaN                       0               2019              NaN
# 3             NaN                       0               2018           2018.0
# 4             NaN                       0               2018           2018.0
# ...           ...                     ...                ...              ...
# 3857          NaN                       0               2019              NaN
# 3858          NaN                       0               2019              NaN
# 3859    6740000.0                       0               2018           2010.0
# 3860    6800000.0                       0               2018           2015.0
# 3861     549000.0                       0               2018           2018.0
#
#       mannual_sum  mannual_dummy  FK_SCORE FALSE_SCOURCES
# 0             0.0            0.0    121.22            0.0
# 1             0.0            0.0     88.74            0.0
# 2             0.0            0.0     68.77            0.0
# 3             1.0            1.0     84.68            0.0
# 4             0.0            0.0     89.75            0.0
# ...           ...            ...       ...            ...
# 3857          0.0            0.0     70.29            0.0
# 3858          0.0            0.0     74.86            0.0
# 3859          0.0            0.0     93.14            0.0
# 3860          0.0            0.0     96.18            0.0
# 3861          0.0            0.0     77.74            0.0
#
# [3862 rows x 85 columns]

# %%
compare_rationality.to_csv("outputs/automated_results/Rationality_FK&fake.csv",index=False)
