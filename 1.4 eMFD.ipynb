# %% [markdown]
# # Implementing Extended Moral Foundations Dictionary (eMFD) for rationality
#
# Hopp, F. R., Fisher, J. T., Cornell, D., Huskey, R., & Weber, R. (2020). The extended Moral Foundations Dictionary (eMFD): Development and applications of a crowd-sourced approach to extracting moral intuitions from text. Behavior Research Methods, https://doi.org/10.3758/s13428-020-01433-0
#
# ## Please download Spacy, its English model and eMFDscore prior to the implementation
# 1. Install spacy (ver 3.4.0): *pip install Spacy*
# 2. Install English model: *python -m spacy download en_core_web_sm*
# 3. Install eMFDscore: *pip install https://github.com/medianeuroscience/emfdscore/archive/master.zip*

# %% [markdown]
# ### Import dataset
# We are going to use both full dataset and train set.

# %%
#Dependencies
import pandas as pd 
import numpy as np
from scipy import stats
import spacy

# %%
#import dataset
full_data = pd.read_csv(r"~\Desktop\Research\Social Media Analysis\publicsphere\data\sample\Data_ReadyForAnalysis_WithComments&MetaInfo.csv")
full_data = full_data[['commentText','ID']] #retain only comment text and comment ID
full_data = full_data.rename(columns={'commentText':0}) #need to be set to 0, otherwise will lead to keyerror

# %% [markdown]
# ### Implementation
# As recommended by the authors, to discriminate which foundations are more or less represented in a text, we are going to use method 2:
# 1. Assign Single Probability per Word and Return Sentiment Scores

# %%
#Assign Single Probability per Word and Return Sentiment Scores
from emfdscore.scoring import score_docs 

num_docs = len(full_data) #select only comment text
 
DICT_TYPE = 'emfd' #use emfd as the dictionary
PROB_MAP = 'single' #assign a single probability to each word in the eMFD according to the foundation with the highest probability
SCORE_METHOD = 'bow' #bow approach (contextless)
OUT_METRICS = 'sentiment' #average sentiment for each foundation

df = score_docs(full_data,DICT_TYPE,PROB_MAP,SCORE_METHOD,OUT_METRICS,num_docs)

df
# Out:
# Processed: 0   0% |                      | Elapsed Time: 0:00:00 ETA:  --:--:--
# Processed: 20   0% |                     | Elapsed Time: 0:00:00 ETA:   0:00:19
# Processed: 48   1% |                     | Elapsed Time: 0:00:00 ETA:   0:00:16
# Processed: 80   2% |                     | Elapsed Time: 0:00:00 ETA:   0:00:14
# Processed: 98   2% |                     | Elapsed Time: 0:00:00 ETA:   0:00:13
# Processed: 123   3% |                    | Elapsed Time: 0:00:00 ETA:   0:00:14
# Processed: 147   3% |                    | Elapsed Time: 0:00:00 ETA:   0:00:13
# Processed: 172   4% |                    | Elapsed Time: 0:00:00 ETA:   0:00:13
# Processed: 196   5% |❤                   | Elapsed Time: 0:00:00 ETA:   0:00:13
# Processed: 223   5% |❤                   | Elapsed Time: 0:00:00 ETA:   0:00:13
# Processed: 245   6% |❤                   | Elapsed Time: 0:00:00 ETA:   0:00:13
# Processed: 269   6% |❤                   | Elapsed Time: 0:00:01 ETA:   0:00:13
# Processed: 293   7% |❤                   | Elapsed Time: 0:00:01 ETA:   0:00:13
# Processed: 319   8% |❤                   | Elapsed Time: 0:00:01 ETA:   0:00:13
# Processed: 339   8% |❤                   | Elapsed Time: 0:00:01 ETA:   0:00:13
# Processed: 363   9% |❤                   | Elapsed Time: 0:00:01 ETA:   0:00:13
# Processed: 392  10% |❤❤                  | Elapsed Time: 0:00:01 ETA:   0:00:13
# Processed: 416  10% |❤❤                  | Elapsed Time: 0:00:01 ETA:   0:00:13
# Processed: 440  11% |❤❤                  | Elapsed Time: 0:00:01 ETA:   0:00:13
# Processed: 462  11% |❤❤                  | Elapsed Time: 0:00:01 ETA:   0:00:13
# Processed: 489  12% |❤❤                  | Elapsed Time: 0:00:01 ETA:   0:00:13
# Processed: 520  13% |❤❤                  | Elapsed Time: 0:00:02 ETA:   0:00:12
# Processed: 531  13% |❤❤                  | Elapsed Time: 0:00:02 ETA:   0:00:13
# Processed: 564  14% |❤❤                  | Elapsed Time: 0:00:02 ETA:   0:00:13
# Processed: 587  15% |❤❤❤                 | Elapsed Time: 0:00:02 ETA:   0:00:13
# Processed: 616  15% |❤❤❤                 | Elapsed Time: 0:00:02 ETA:   0:00:12
# Processed: 636  16% |❤❤❤                 | Elapsed Time: 0:00:02 ETA:   0:00:12
# Processed: 672  17% |❤❤❤                 | Elapsed Time: 0:00:02 ETA:   0:00:12
# Processed: 705  18% |❤❤❤                 | Elapsed Time: 0:00:02 ETA:   0:00:12
# Processed: 734  19% |❤❤❤                 | Elapsed Time: 0:00:02 ETA:   0:00:12
# Processed: 768  19% |❤❤❤                 | Elapsed Time: 0:00:02 ETA:   0:00:11
# Processed: 802  20% |❤❤❤❤                | Elapsed Time: 0:00:03 ETA:   0:00:11
# Processed: 832  21% |❤❤❤❤                | Elapsed Time: 0:00:03 ETA:   0:00:11
# Processed: 865  22% |❤❤❤❤                | Elapsed Time: 0:00:03 ETA:   0:00:11
# Processed: 900  23% |❤❤❤❤                | Elapsed Time: 0:00:03 ETA:   0:00:10
# Processed: 929  24% |❤❤❤❤                | Elapsed Time: 0:00:03 ETA:   0:00:10
# Processed: 966  25% |❤❤❤❤❤               | Elapsed Time: 0:00:03 ETA:   0:00:10
# Processed: 1002  25% |❤❤❤❤               | Elapsed Time: 0:00:03 ETA:   0:00:10
# Processed: 1027  26% |❤❤❤❤❤              | Elapsed Time: 0:00:03 ETA:   0:00:10
# Processed: 1062  27% |❤❤❤❤❤              | Elapsed Time: 0:00:03 ETA:   0:00:09
# Processed: 1100  28% |❤❤❤❤❤              | Elapsed Time: 0:00:03 ETA:   0:00:09
# Processed: 1125  29% |❤❤❤❤❤              | Elapsed Time: 0:00:03 ETA:   0:00:09
# Processed: 1160  30% |❤❤❤❤❤              | Elapsed Time: 0:00:04 ETA:   0:00:09
# Processed: 1196  30% |❤❤❤❤❤              | Elapsed Time: 0:00:04 ETA:   0:00:09
# Processed: 1223  31% |❤❤❤❤❤❤             | Elapsed Time: 0:00:04 ETA:   0:00:09
# Processed: 1260  32% |❤❤❤❤❤❤             | Elapsed Time: 0:00:04 ETA:   0:00:08
# Processed: 1296  33% |❤❤❤❤❤❤             | Elapsed Time: 0:00:04 ETA:   0:00:08
# Processed: 1320  34% |❤❤❤❤❤❤             | Elapsed Time: 0:00:04 ETA:   0:00:08
# Processed: 1357  35% |❤❤❤❤❤❤             | Elapsed Time: 0:00:04 ETA:   0:00:08
# Processed: 1391  36% |❤❤❤❤❤❤             | Elapsed Time: 0:00:04 ETA:   0:00:08
# Processed: 1415  36% |❤❤❤❤❤❤             | Elapsed Time: 0:00:04 ETA:   0:00:08
# Processed: 1445  37% |❤❤❤❤❤❤❤            | Elapsed Time: 0:00:04 ETA:   0:00:08
# Processed: 1467  37% |❤❤❤❤❤❤❤            | Elapsed Time: 0:00:04 ETA:   0:00:08
# Processed: 1496  38% |❤❤❤❤❤❤❤            | Elapsed Time: 0:00:05 ETA:   0:00:08
# Processed: 1512  39% |❤❤❤❤❤❤❤            | Elapsed Time: 0:00:05 ETA:   0:00:08
# Processed: 1534  39% |❤❤❤❤❤❤❤            | Elapsed Time: 0:00:05 ETA:   0:00:08
# Processed: 1558  40% |❤❤❤❤❤❤❤            | Elapsed Time: 0:00:05 ETA:   0:00:07
# Processed: 1588  41% |❤❤❤❤❤❤❤            | Elapsed Time: 0:00:05 ETA:   0:00:07
# Processed: 1603  41% |❤❤❤❤❤❤❤            | Elapsed Time: 0:00:05 ETA:   0:00:07
# Processed: 1631  42% |❤❤❤❤❤❤❤❤           | Elapsed Time: 0:00:05 ETA:   0:00:07
# Processed: 1663  43% |❤❤❤❤❤❤❤❤           | Elapsed Time: 0:00:05 ETA:   0:00:07
# Processed: 1689  43% |❤❤❤❤❤❤❤❤           | Elapsed Time: 0:00:05 ETA:   0:00:07
# Processed: 1708  44% |❤❤❤❤❤❤❤❤           | Elapsed Time: 0:00:06 ETA:   0:00:07
# Processed: 1733  44% |❤❤❤❤❤❤❤❤           | Elapsed Time: 0:00:06 ETA:   0:00:07
# Processed: 1760  45% |❤❤❤❤❤❤❤❤           | Elapsed Time: 0:00:06 ETA:   0:00:07
# Processed: 1791  46% |❤❤❤❤❤❤❤❤           | Elapsed Time: 0:00:06 ETA:   0:00:07
# Processed: 1809  46% |❤❤❤❤❤❤❤❤           | Elapsed Time: 0:00:06 ETA:   0:00:07
# Processed: 1834  47% |❤❤❤❤❤❤❤❤❤          | Elapsed Time: 0:00:06 ETA:   0:00:07
# Processed: 1858  48% |❤❤❤❤❤❤❤❤❤          | Elapsed Time: 0:00:06 ETA:   0:00:07
# Processed: 1888  48% |❤❤❤❤❤❤❤❤❤          | Elapsed Time: 0:00:06 ETA:   0:00:06
# Processed: 1907  49% |❤❤❤❤❤❤❤❤❤          | Elapsed Time: 0:00:06 ETA:   0:00:06
# Processed: 1923  49% |❤❤❤❤❤❤❤❤❤          | Elapsed Time: 0:00:06 ETA:   0:00:06
# Processed: 1945  50% |❤❤❤❤❤❤❤❤❤          | Elapsed Time: 0:00:07 ETA:   0:00:06
# Processed: 1956  50% |❤❤❤❤❤❤❤❤❤          | Elapsed Time: 0:00:07 ETA:   0:00:06
# Processed: 1981  51% |❤❤❤❤❤❤❤❤❤          | Elapsed Time: 0:00:07 ETA:   0:00:06
# Processed: 2005  51% |❤❤❤❤❤❤❤❤❤          | Elapsed Time: 0:00:07 ETA:   0:00:06
# Processed: 2028  52% |❤❤❤❤❤❤❤❤❤          | Elapsed Time: 0:00:07 ETA:   0:00:06
# Processed: 2051  53% |❤❤❤❤❤❤❤❤❤❤         | Elapsed Time: 0:00:07 ETA:   0:00:06
# Processed: 2080  53% |❤❤❤❤❤❤❤❤❤❤         | Elapsed Time: 0:00:07 ETA:   0:00:06
# Processed: 2103  54% |❤❤❤❤❤❤❤❤❤❤         | Elapsed Time: 0:00:07 ETA:   0:00:06
# Processed: 2130  55% |❤❤❤❤❤❤❤❤❤❤         | Elapsed Time: 0:00:07 ETA:   0:00:06
# Processed: 2151  55% |❤❤❤❤❤❤❤❤❤❤         | Elapsed Time: 0:00:07 ETA:   0:00:06
# Processed: 2182  56% |❤❤❤❤❤❤❤❤❤❤         | Elapsed Time: 0:00:07 ETA:   0:00:06
# Processed: 2200  56% |❤❤❤❤❤❤❤❤❤❤         | Elapsed Time: 0:00:08 ETA:   0:00:06
# Processed: 2232  57% |❤❤❤❤❤❤❤❤❤❤         | Elapsed Time: 0:00:08 ETA:   0:00:05
# Processed: 2262  58% |❤❤❤❤❤❤❤❤❤❤❤        | Elapsed Time: 0:00:08 ETA:   0:00:05
# Processed: 2291  59% |❤❤❤❤❤❤❤❤❤❤❤        | Elapsed Time: 0:00:08 ETA:   0:00:05
# Processed: 2319  60% |❤❤❤❤❤❤❤❤❤❤❤        | Elapsed Time: 0:00:08 ETA:   0:00:05
# Processed: 2342  60% |❤❤❤❤❤❤❤❤❤❤❤        | Elapsed Time: 0:00:08 ETA:   0:00:05
# Processed: 2367  61% |❤❤❤❤❤❤❤❤❤❤❤        | Elapsed Time: 0:00:08 ETA:   0:00:05
# Processed: 2392  61% |❤❤❤❤❤❤❤❤❤❤❤        | Elapsed Time: 0:00:08 ETA:   0:00:05
# Processed: 2411  62% |❤❤❤❤❤❤❤❤❤❤❤        | Elapsed Time: 0:00:08 ETA:   0:00:05
# Processed: 2435  63% |❤❤❤❤❤❤❤❤❤❤❤        | Elapsed Time: 0:00:08 ETA:   0:00:05
# Processed: 2445  63% |❤❤❤❤❤❤❤❤❤❤❤❤       | Elapsed Time: 0:00:09 ETA:   0:00:05
# Processed: 2477  64% |❤❤❤❤❤❤❤❤❤❤❤❤       | Elapsed Time: 0:00:09 ETA:   0:00:05
# Processed: 2494  64% |❤❤❤❤❤❤❤❤❤❤❤❤       | Elapsed Time: 0:00:09 ETA:   0:00:05
# Processed: 2518  65% |❤❤❤❤❤❤❤❤❤❤❤❤       | Elapsed Time: 0:00:09 ETA:   0:00:04
# Processed: 2543  65% |❤❤❤❤❤❤❤❤❤❤❤❤       | Elapsed Time: 0:00:09 ETA:   0:00:04
# Processed: 2575  66% |❤❤❤❤❤❤❤❤❤❤❤❤       | Elapsed Time: 0:00:09 ETA:   0:00:04
# Processed: 2591  67% |❤❤❤❤❤❤❤❤❤❤❤❤       | Elapsed Time: 0:00:09 ETA:   0:00:04
# Processed: 2618  67% |❤❤❤❤❤❤❤❤❤❤❤❤       | Elapsed Time: 0:00:09 ETA:   0:00:04
# Processed: 2640  68% |❤❤❤❤❤❤❤❤❤❤❤❤       | Elapsed Time: 0:00:09 ETA:   0:00:04
# Processed: 2664  68% |❤❤❤❤❤❤❤❤❤❤❤❤❤      | Elapsed Time: 0:00:09 ETA:   0:00:04
# Processed: 2688  69% |❤❤❤❤❤❤❤❤❤❤❤❤❤      | Elapsed Time: 0:00:09 ETA:   0:00:04
# Processed: 2716  70% |❤❤❤❤❤❤❤❤❤❤❤❤❤      | Elapsed Time: 0:00:10 ETA:   0:00:04
# Processed: 2738  70% |❤❤❤❤❤❤❤❤❤❤❤❤❤      | Elapsed Time: 0:00:10 ETA:   0:00:04
# Processed: 2760  71% |❤❤❤❤❤❤❤❤❤❤❤❤❤      | Elapsed Time: 0:00:10 ETA:   0:00:04
# Processed: 2787  72% |❤❤❤❤❤❤❤❤❤❤❤❤❤      | Elapsed Time: 0:00:10 ETA:   0:00:03
# Processed: 2807  72% |❤❤❤❤❤❤❤❤❤❤❤❤❤      | Elapsed Time: 0:00:10 ETA:   0:00:03
# Processed: 2836  73% |❤❤❤❤❤❤❤❤❤❤❤❤❤      | Elapsed Time: 0:00:10 ETA:   0:00:03
# Processed: 2862  74% |❤❤❤❤❤❤❤❤❤❤❤❤❤❤     | Elapsed Time: 0:00:10 ETA:   0:00:03
# Processed: 2885  74% |❤❤❤❤❤❤❤❤❤❤❤❤❤❤     | Elapsed Time: 0:00:10 ETA:   0:00:03
# Processed: 2911  75% |❤❤❤❤❤❤❤❤❤❤❤❤❤❤     | Elapsed Time: 0:00:10 ETA:   0:00:03
# Processed: 2934  75% |❤❤❤❤❤❤❤❤❤❤❤❤❤❤     | Elapsed Time: 0:00:10 ETA:   0:00:03
# Processed: 2963  76% |❤❤❤❤❤❤❤❤❤❤❤❤❤❤     | Elapsed Time: 0:00:10 ETA:   0:00:03
# Processed: 2983  77% |❤❤❤❤❤❤❤❤❤❤❤❤❤❤     | Elapsed Time: 0:00:11 ETA:   0:00:03
# Processed: 3014  78% |❤❤❤❤❤❤❤❤❤❤❤❤❤❤     | Elapsed Time: 0:00:11 ETA:   0:00:03
# Processed: 3031  78% |❤❤❤❤❤❤❤❤❤❤❤❤❤❤     | Elapsed Time: 0:00:11 ETA:   0:00:03
# Processed: 3054  79% |❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤    | Elapsed Time: 0:00:11 ETA:   0:00:02
# Processed: 3079  79% |❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤    | Elapsed Time: 0:00:11 ETA:   0:00:02
# Processed: 3112  80% |❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤    | Elapsed Time: 0:00:11 ETA:   0:00:02
# Processed: 3129  81% |❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤    | Elapsed Time: 0:00:11 ETA:   0:00:02
# Processed: 3162  81% |❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤    | Elapsed Time: 0:00:11 ETA:   0:00:02
# Processed: 3178  82% |❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤    | Elapsed Time: 0:00:11 ETA:   0:00:02
# Processed: 3208  83% |❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤    | Elapsed Time: 0:00:11 ETA:   0:00:02
# Processed: 3227  83% |❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤    | Elapsed Time: 0:00:11 ETA:   0:00:02
# Processed: 3254  84% |❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤   | Elapsed Time: 0:00:12 ETA:   0:00:02
# Processed: 3276  84% |❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤   | Elapsed Time: 0:00:12 ETA:   0:00:02
# Processed: 3308  85% |❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤   | Elapsed Time: 0:00:12 ETA:   0:00:02
# Processed: 3325  86% |❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤   | Elapsed Time: 0:00:12 ETA:   0:00:01
# Processed: 3357  86% |❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤   | Elapsed Time: 0:00:12 ETA:   0:00:01
# Processed: 3374  87% |❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤   | Elapsed Time: 0:00:12 ETA:   0:00:01
# Processed: 3403  88% |❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤   | Elapsed Time: 0:00:12 ETA:   0:00:01
# Processed: 3423  88% |❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤   | Elapsed Time: 0:00:12 ETA:   0:00:01
# Processed: 3454  89% |❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤   | Elapsed Time: 0:00:12 ETA:   0:00:01
# Processed: 3471  89% |❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤  | Elapsed Time: 0:00:12 ETA:   0:00:01
# Processed: 3495  90% |❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤  | Elapsed Time: 0:00:12 ETA:   0:00:01
# Processed: 3516  91% |❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤  | Elapsed Time: 0:00:13 ETA:   0:00:01
# Processed: 3545  91% |❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤  | Elapsed Time: 0:00:13 ETA:   0:00:01
# Processed: 3569  92% |❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤  | Elapsed Time: 0:00:13 ETA:   0:00:01
# Processed: 3602  93% |❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤  | Elapsed Time: 0:00:13 ETA:   0:00:00
# Processed: 3618  93% |❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤  | Elapsed Time: 0:00:13 ETA:   0:00:00
# Processed: 3649  94% |❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤  | Elapsed Time: 0:00:13 ETA:   0:00:00
# Processed: 3667  94% |❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤ | Elapsed Time: 0:00:13 ETA:   0:00:00
# Processed: 3699  95% |❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤ | Elapsed Time: 0:00:13 ETA:   0:00:00
# Processed: 3716  96% |❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤ | Elapsed Time: 0:00:13 ETA:   0:00:00
# Processed: 3743  96% |❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤ | Elapsed Time: 0:00:13 ETA:   0:00:00
# Processed: 3765  97% |❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤ | Elapsed Time: 0:00:13 ETA:   0:00:00
# Processed: 3799  98% |❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤ | Elapsed Time: 0:00:13 ETA:   0:00:00
# Processed: 3814  98% |❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤ | Elapsed Time: 0:00:14 ETA:   0:00:00
# Processed: 3835  99% |❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤ | Elapsed Time: 0:00:14 ETA:   0:00:00
# Processed: 3862 100% |❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤| Elapsed Time: 0:00:14 Time:  0:00:14
#         care_p  fairness_p  loyalty_p  authority_p  sanctity_p  care_sent  \
# 0     0.185185    0.000000   0.000000     0.000000    0.000000  -0.291760
# 1     0.038095    0.098627   0.036405     0.000000    0.000000  -0.106818
# 2     0.071429    0.053635   0.000000     0.037500    0.000000   0.028342
# 3     0.058345    0.032072   0.016008     0.030516    0.012626  -0.105237
# 4     0.000000    0.000000   0.000000     0.000000    0.000000   0.000000
# ...        ...         ...        ...          ...         ...        ...
# 3857  0.078012    0.052659   0.026260     0.000000    0.000000  -0.022988
# 3858  0.000000    0.000000   0.000000     0.081633    0.000000   0.000000
# 3859  0.039031    0.019687   0.008003     0.040979    0.008475  -0.082759
# 3860  0.037715    0.048842   0.034504     0.020918    0.012500   0.006129
# 3861  0.080133    0.000000   0.020132     0.099952    0.019481  -0.142565
#
#       fairness_sent  loyalty_sent  authority_sent  sanctity_sent  \
# 0          0.000000      0.000000        0.000000       0.000000
# 1          0.018554      0.062361        0.000000       0.000000
# 2         -0.068767      0.000000        0.022872       0.000000
# 3          0.026819     -0.009292       -0.057323       0.015111
# 4          0.000000      0.000000        0.000000       0.000000
# ...             ...           ...             ...            ...
# 3857      -0.000511      0.043429        0.000000       0.000000
# 3858       0.000000      0.000000       -0.170325       0.000000
# 3859      -0.017446      0.028764       -0.040175       0.001157
# 3860       0.001440      0.043606       -0.024904      -0.019173
# 3861       0.000000     -0.010157       -0.119665      -0.012337
#
#       moral_nonmoral_ratio     f_var  sent_var
# 0                 1.000000  0.006859  0.017025
# 1                 1.400000  0.001627  0.003877
# 2                 1.000000  0.001025  0.001498
# 3                 1.500000  0.000326  0.003005
# 4                 0.000000  0.000000  0.000000
# ...                    ...       ...       ...
# 3857              1.000000  0.001156  0.000584
# 3858              0.333333  0.001333  0.005802
# 3859              1.750000  0.000257  0.001789
# 3860              1.111111  0.000205  0.000730
# 3861              0.538462  0.001886  0.004672
#
# [3862 rows x 13 columns]

# %% [markdown]
# ### Labelling conservative and liberals by likelihood
#
# Conservatives and liberals are assumed to use distinct foundations while expressing opinions:
# 1. Liberals: Care and fairness
# 2. Conservatives: Loyalty, authority and sanctity

# %%
#Retain only useful columns
clean_df = df[['care_p','fairness_p','loyalty_p','authority_p','sanctity_p']]

#create max_likelihood_dict for storing likelihood and ideology
column_names = ['Liberal_foundation_likelihood', 'Conservative_foundation_likelihood', 'Likelihood_distance', 'Ideology']
max_likelihood_dict = pd.DataFrame(columns=column_names)


#Get max likelihood from both liberal and conservative foundations
max_likelihood_dict['Liberal_foundation_likelihood'] = clean_df[['care_p','fairness_p']].max(axis = 1) 
max_likelihood_dict['Conservative_foundation_likelihood'] = clean_df[['loyalty_p','authority_p','sanctity_p']].max(axis = 1)

#Get the likelihood distance between liberal and conservative
max_likelihood_dict['Likelihood_distance'] = max_likelihood_dict['Liberal_foundation_likelihood'] - max_likelihood_dict['Conservative_foundation_likelihood']

max_likelihood_dict['Ideology'] = max_likelihood_dict.apply(lambda x: 'Liberal' if x['Likelihood_distance'] >= 0 else 'Conservative', axis = 1)

max_likelihood_dict.head(5)
# Out:
#    Liberal_foundation_likelihood  Conservative_foundation_likelihood  \
# 0                       0.185185                            0.000000
# 1                       0.098627                            0.036405
# 2                       0.071429                            0.037500
# 3                       0.058345                            0.030516
# 4                       0.000000                            0.000000
#
#    Likelihood_distance Ideology
# 0             0.185185  Liberal
# 1             0.062222  Liberal
# 2             0.033929  Liberal
# 3             0.027829  Liberal
# 4             0.000000  Liberal

# %%
max_likelihood_dict
# Out:
#       Liberal_foundation_likelihood  Conservative_foundation_likelihood  \
# 0                          0.185185                            0.000000
# 1                          0.098627                            0.036405
# 2                          0.071429                            0.037500
# 3                          0.058345                            0.030516
# 4                          0.000000                            0.000000
# ...                             ...                                 ...
# 3857                       0.078012                            0.026260
# 3858                       0.000000                            0.081633
# 3859                       0.039031                            0.040979
# 3860                       0.048842                            0.034504
# 3861                       0.080133                            0.099952
#
#       Likelihood_distance      Ideology
# 0                0.185185       Liberal
# 1                0.062222       Liberal
# 2                0.033929       Liberal
# 3                0.027829       Liberal
# 4                0.000000       Liberal
# ...                   ...           ...
# 3857             0.051752       Liberal
# 3858            -0.081633  Conservative
# 3859            -0.001947  Conservative
# 3860             0.014338       Liberal
# 3861            -0.019820  Conservative
#
# [3862 rows x 4 columns]

# %%
#Merge with original document
max_likelihood_dict = max_likelihood_dict.merge(full_data, left_index=True, right_index=True)

#rename columns
max_likelihood_dict = max_likelihood_dict.rename(columns = {0:'commentText'})

print("Full dataset:\n----------------------------------------------")
display(max_likelihood_dict)

#Create df with rows contained in train set
train_set = pd.read_csv(r"C:\Users\shrim\Desktop\Research\Social Media Analysis\publicsphere\data\sample\test_train_split\train.csv")
train_set = train_set[['ID']] #retain only comment ID

print("Train set subset:\n----------------------------------------------")
train_set_merge = train_set.merge(how = 'left',right = max_likelihood_dict, on='ID')
display(train_set_merge)

#export csv
max_likelihood_dict.to_csv('emfd_diversity.csv', index=False)
train_set_merge.to_csv('emfd_diversity_train_set.csv', index=False)
# Out:
# Full dataset:
# ----------------------------------------------
#       Liberal_foundation_likelihood  Conservative_foundation_likelihood  \
# 0                          0.185185                            0.000000
# 1                          0.098627                            0.036405
# 2                          0.071429                            0.037500
# 3                          0.058345                            0.030516
# 4                          0.000000                            0.000000
# ...                             ...                                 ...
# 3857                       0.078012                            0.026260
# 3858                       0.000000                            0.081633
# 3859                       0.039031                            0.040979
# 3860                       0.048842                            0.034504
# 3861                       0.080133                            0.099952
#
#       Likelihood_distance      Ideology  \
# 0                0.185185       Liberal
# 1                0.062222       Liberal
# 2                0.033929       Liberal
# 3                0.027829       Liberal
# 4                0.000000       Liberal
# ...                   ...           ...
# 3857             0.051752       Liberal
# 3858            -0.081633  Conservative
# 3859            -0.001947  Conservative
# 3860             0.014338       Liberal
# 3861            -0.019820  Conservative
#
#                                             commentText  \
# 0                                                   sad
# 1     That's a vicious insult!!! What did a box of r...
# 2     @colbertlateshow The question has always been ...
# 3     Goya Solidar.  So there are a few of us left. ...
# 4             hello hello \r\nNo-one else will hug him.
# ...                                                 ...
# 3857  @FullFrontalSamB They can’t afford chemical pe...
# 3858  @AC360 @CNN @andersoncooper It's not if..... h...
# 3859  Nah, they knew all about the cameras.  I'm gue...
# 3860  Alexander Hamilton. Troops are waiting in the ...
# 3861  The Syrian crisis is a horrible thing, but has...
#
#                                                      ID
# 0     UgyPHwv8G0cDE6-wEgl4AaABAg.8_0ZjJKSJty8_0kXGkAd2U
# 1     Ugx2WXq9UdV8mPPjejJ4AaABAg.8yHCKV0Boe58yYRxEQEF45
# 2                                   1110578710648890000
# 3     UgwUPFScjJ0MCeaP2F54AaABAg.8lvp3fc9Euf8lvvgsUgEgV
# 4     UgwWKCWtSJdFvjGHvTp4AaABAg.8kUC5dGrQ2H8kUDRihE2f3
# ...                                                 ...
# 3857                                1152219467579100000
# 3858                                1085362296472430000
# 3859        UghFY3QJ6nmT_ngCoAEC.7-H0Z7--wxd8goqpaPs-bl
# 3860                         UgyWabsmmnq3zam4DgZ4AaABAg
# 3861                         UgwPOHIDyICm10k0Mvx4AaABAg
#
# [3862 rows x 6 columns]
# Train set subset:
# ----------------------------------------------
#                                                      ID  \
# 0     UgyPHwv8G0cDE6-wEgl4AaABAg.8_0ZjJKSJty8_0kXGkAd2U
# 1     Ugx2WXq9UdV8mPPjejJ4AaABAg.8yHCKV0Boe58yYRxEQEF45
# 2                                   1110578710648890000
# 3     UgwUPFScjJ0MCeaP2F54AaABAg.8lvp3fc9Euf8lvvgsUgEgV
# 4     UgwWKCWtSJdFvjGHvTp4AaABAg.8kUC5dGrQ2H8kUDRihE2f3
# ...                                                 ...
# 3084                                1152219467579100000
# 3085                                1085362296472430000
# 3086        UghFY3QJ6nmT_ngCoAEC.7-H0Z7--wxd8goqpaPs-bl
# 3087                         UgyWabsmmnq3zam4DgZ4AaABAg
# 3088                         UgwPOHIDyICm10k0Mvx4AaABAg
#
#       Liberal_foundation_likelihood  Conservative_foundation_likelihood  \
# 0                          0.185185                            0.000000
# 1                          0.098627                            0.036405
# 2                          0.071429                            0.037500
# 3                          0.058345                            0.030516
# 4                          0.000000                            0.000000
# ...                             ...                                 ...
# 3084                       0.078012                            0.026260
# 3085                       0.000000                            0.081633
# 3086                       0.039031                            0.040979
# 3087                       0.048842                            0.034504
# 3088                       0.080133                            0.099952
#
#       Likelihood_distance      Ideology  \
# 0                0.185185       Liberal
# 1                0.062222       Liberal
# 2                0.033929       Liberal
# 3                0.027829       Liberal
# 4                0.000000       Liberal
# ...                   ...           ...
# 3084             0.051752       Liberal
# 3085            -0.081633  Conservative
# 3086            -0.001947  Conservative
# 3087             0.014338       Liberal
# 3088            -0.019820  Conservative
#
#                                             commentText
# 0                                                   sad
# 1     That's a vicious insult!!! What did a box of r...
# 2     @colbertlateshow The question has always been ...
# 3     Goya Solidar.  So there are a few of us left. ...
# 4             hello hello \r\nNo-one else will hug him.
# ...                                                 ...
# 3084  @FullFrontalSamB They can’t afford chemical pe...
# 3085  @AC360 @CNN @andersoncooper It's not if..... h...
# 3086  Nah, they knew all about the cameras.  I'm gue...
# 3087  Alexander Hamilton. Troops are waiting in the ...
# 3088  The Syrian crisis is a horrible thing, but has...
#
# [3089 rows x 6 columns]
